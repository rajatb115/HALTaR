# %%
import sys
sys.path.append("/mnt/data/phantom/rajat/table_qa/Table_QA/train_struBERT")

# %%
import os
import torch
from utils import load_checkpoint_for_eval
from table_matching_model import strubert_embd
import numpy as np
# Out:
# WARNING:root:You are using the old version of `pytorch_pretrained_bert`
# /home/srajat/anaconda3/envs/strubert/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/srajat/anaconda3/envs/strubert/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/srajat/anaconda3/envs/strubert/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/srajat/anaconda3/envs/strubert/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/srajat/anaconda3/envs/strubert/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/srajat/anaconda3/envs/strubert/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
os.environ['http_proxy']="http://proxy61.iitd.ac.in:3128"
os.environ['https_proxy']="http://proxy61.iitd.ac.in:3128"

# %% [markdown]
# ## Creating the dataset for processing SPIDER dataset
# ### Processing the query tables

# %%
m_parm_setting = f'default_model'
parm_setting = f'no_aug'
# model_setting = "batch_4_epoch_8_lr_3e-05"

query_path_output = "../../dataset/spider/processing/query"

result_path = f"../../output/spider_res/default_{m_parm_setting}_{parm_setting}/"

corpus_path_output = f"../../dataset/spider/processing/corpus/"

corpus_folder = corpus_path_output
query_folder = query_path_output

# %%
# # checking if the folder exist in that path

# if not os.path.exists(query_path_output):
#     os.makedirs(query_path_output)
#     print("folder created...")
# else:
#     print("folder already exist...")

# %%
# import shutil
# import os

# # renaming the json
# # the json should start with 're_tables-' + file_number + '.json'
# # the table should be name with 'table-' + file_number + '-' + table_number

# files = []

# # checking the number of files in query_tables path
# if os.path.exists(query_path) and os.path.isdir(query_path):
#     files = [f for f in os.listdir(query_path) if os.path.isfile(os.path.join(query_path, f))]
#     print(files)
# else:
#     print(f"Folder not found at {query_path}")

# # Now copying these files to query_and_corpus folder
# if len(files) != 0:
#     for f in files:
#         name = f.strip().split(".")[0].strip().split("_")[1]
#         shutil.copyfile(os.path.join(query_path,f), os.path.join(query_path_output,f"re_tables-{name}.json"))

# %%
# import json

# # Now preprocessing the tables
# files = [f for f in os.listdir(query_path_output) if os.path.isfile(os.path.join(query_path_output, f))]

# for f in files:
#     # print(f)
#     with open(os.path.join(query_path_output,f), 'r') as fp:
#         data = json.load(fp)

#     data2 = {}
#     data2[f'table-{f.strip().split(".")[0].split("-")[1]}-{f.strip().split(".")[0].split("-")[1]}'] = data[f'table_{f.strip().split(".")[0].split("-")[1]}']

#     with open(os.path.join(query_path_output,f),'w') as fp:
#         json.dump(data2, fp, indent=4)

# print("Processing of the queries completed...")

# %% [markdown]
# ### Processing the corpus tables

# %%
# # checking if the folder exist in that path

# if not os.path.exists(corpus_path_output):
#     os.makedirs(corpus_path_output)
#     print("folder created...")
# else:
#     print("folder already exist...")

# %%
# import shutil
# import os

# # renaming the json
# # the json should start with 're_tables-' + file_number + '.json'
# # the table should be name with 'table-' + file_number + '-' + table_number

# files_corpus = []

# # checking the number of files in query_tables path
# if os.path.exists(corpus_path) and os.path.isdir(corpus_path):
#     files_corpus = [f for f in os.listdir(corpus_path) if os.path.isfile(os.path.join(corpus_path, f))]
#     print(files_corpus)
# else:
#     print(f"Folder not found at {corpus_path}")

# # Now copying these files to query_and_corpus folder
# if len(files_corpus) != 0:
#     for f in files_corpus:
#         name = f.strip().split(".")[0]
#         shutil.copyfile(os.path.join(corpus_path,f), os.path.join(corpus_path_output,f"re_tables-{name}.json"))

# print("Processing completed")

# %% [markdown]
# ## Loading the Model

# %%
# Load the best model from the database
# save_path_best = f'../../output/finetune_model/bird/{model_setting}_{run_number}_{m_parm_setting}/best_bird_tabert_1.pt'
tabert_path = "../../model/tabert_base_k3/model.bin"
device = "cuda:3"

# %%
print("CUDA Available:", torch.cuda.is_available())
print("CUDA Device Count:", torch.cuda.device_count())
print("Current CUDA Device:", torch.cuda.current_device())
# Out:
# CUDA Available: True
# CUDA Device Count: 4
# Current CUDA Device: 0

# %%
# Loading the model
model = strubert_embd(tabert_path=tabert_path, device=device)

# %%
# Assume this is your loaded model

# model = load_checkpoint_for_eval(model, save_path_best, device=device)
model.eval()
# Out:
# strubert_embd(
#   (embedding): VerticalAttentionTableBert(
#     (_bert_model): BertForMaskedLM(
#       (bert): BertModel(
#         (embeddings): BertEmbeddings(
#           (word_embeddings): Embedding(30522, 768, padding_idx=0)
#           (position_embeddings): Embedding(512, 768)
#           (token_type_embeddings): Embedding(2, 768)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1)
#         )
#         (encoder): BertEncoder(
#           (layer): ModuleList(
#             (0): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): BertLayerNorm()
#                   (dropout): Dropout(p=0.1)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): BertLayerNorm()
#                 (dropout): Dropout(p=0.1)
#               )
#             )
#             (1): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): BertLayerNorm()
#                   (dropout): Dropout(p=0.1)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): BertLayerNorm()
#                 (dropout): Dropout(p=0.1)
#               )
#             )
#             (2): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): BertLayerNorm()
#                   (dropout): Dropout(p=0.1)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): BertLayerNorm()
#                 (dropout): Dropout(p=0.1)
#               )
#             )
#             (3): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): BertLayerNorm()
#                   (dropout): Dropout(p=0.1)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): BertLayerNorm()
#                 (dropout): Dropout(p=0.1)
#               )
#             )
#             (4): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): BertLayerNorm()
#                   (dropout): Dropout(p=0.1)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): BertLayerNorm()
#                 (dropout): Dropout(p=0.1)
#               )
#             )
#             (5): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): BertLayerNorm()
#                   (dropout): Dropout(p=0.1)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): BertLayerNorm()
#                 (dropout): Dropout(p=0.1)
#               )
#             )
#             (6): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): BertLayerNorm()
#                   (dropout): Dropout(p=0.1)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): BertLayerNorm()
#                 (dropout): Dropout(p=0.1)
#               )
#             )
#             (7): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): BertLayerNorm()
#                   (dropout): Dropout(p=0.1)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): BertLayerNorm()
#                 (dropout): Dropout(p=0.1)
#               )
#             )
#             (8): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): BertLayerNorm()
#                   (dropout): Dropout(p=0.1)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): BertLayerNorm()
#                 (dropout): Dropout(p=0.1)
#               )
#             )
#             (9): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): BertLayerNorm()
#                   (dropout): Dropout(p=0.1)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): BertLayerNorm()
#                 (dropout): Dropout(p=0.1)
#               )
#             )
#             (10): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): BertLayerNorm()
#                   (dropout): Dropout(p=0.1)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): BertLayerNorm()
#                 (dropout): Dropout(p=0.1)
#               )
#             )
#             (11): BertLayer(
#               (attention): BertAttention(
#                 (self): BertSelfAttention(
#                   (query): Linear(in_features=768, out_features=768, bias=True)
#                   (key): Linear(in_features=768, out_features=768, bias=True)
#                   (value): Linear(in_features=768, out_features=768, bias=True)
#                   (dropout): Dropout(p=0.1)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): BertLayerNorm()
#                   (dropout): Dropout(p=0.1)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear(in_features=768, out_features=3072, bias=True)
#               )
#               (output): BertOutput(
#                 (dense): Linear(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): BertLayerNorm()
#                 (dropout): Dropout(p=0.1)
#               )
#             )
#           )
#         )
#         (pooler): BertPooler(
#           (dense): Linear(in_features=768, out_features=768, bias=True)
#           (activation): Tanh()
#         )
#       )
#       (cls): BertOnlyMLMHead(
#         (predictions): BertLMPredictionHead(
#           (transform): BertPredictionHeadTransform(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#           )
#           (decoder): Linear(in_features=768, out_features=30522, bias=False)
#         )
#       )
#     )
#     (span_based_prediction): SpanBasedPrediction(
#       (dense1): Linear(in_features=1536, out_features=768, bias=False)
#       (layer_norm1): BertLayerNorm()
#       (dense2): Linear(in_features=768, out_features=768, bias=False)
#       (layer_norm2): BertLayerNorm()
#       (prediction): BertLMPredictionHead(
#         (transform): BertPredictionHeadTransform(
#           (dense): Linear(in_features=768, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#         )
#         (decoder): Linear(in_features=768, out_features=30522, bias=False)
#       )
#     )
#     (vertical_embedding_layer): VerticalEmbeddingLayer()
#     (vertical_transformer_layers): ModuleList(
#       (0): BertVerticalLayer(
#         (attention): BertVerticalAttention(
#           (self_attention): VerticalSelfAttention(
#             (query_linear): Linear(in_features=768, out_features=768, bias=True)
#             (key_linear): Linear(in_features=768, out_features=768, bias=True)
#             (value_linear): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1)
#           )
#           (self_output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (1): BertVerticalLayer(
#         (attention): BertVerticalAttention(
#           (self_attention): VerticalSelfAttention(
#             (query_linear): Linear(in_features=768, out_features=768, bias=True)
#             (key_linear): Linear(in_features=768, out_features=768, bias=True)
#             (value_linear): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1)
#           )
#           (self_output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (2): BertVerticalLayer(
#         (attention): BertVerticalAttention(
#           (self_attention): VerticalSelfAttention(
#             (query_linear): Linear(in_features=768, out_features=768, bias=True)
#             (key_linear): Linear(in_features=768, out_features=768, bias=True)
#             (value_linear): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1)
#           )
#           (self_output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#     )
#     (row_vertical_transformer_layers): ModuleList(
#       (0): BertVerticalLayer(
#         (attention): BertVerticalAttention(
#           (self_attention): VerticalSelfAttention(
#             (query_linear): Linear(in_features=768, out_features=768, bias=True)
#             (key_linear): Linear(in_features=768, out_features=768, bias=True)
#             (value_linear): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1)
#           )
#           (self_output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (1): BertVerticalLayer(
#         (attention): BertVerticalAttention(
#           (self_attention): VerticalSelfAttention(
#             (query_linear): Linear(in_features=768, out_features=768, bias=True)
#             (key_linear): Linear(in_features=768, out_features=768, bias=True)
#             (value_linear): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1)
#           )
#           (self_output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (2): BertVerticalLayer(
#         (attention): BertVerticalAttention(
#           (self_attention): VerticalSelfAttention(
#             (query_linear): Linear(in_features=768, out_features=768, bias=True)
#             (key_linear): Linear(in_features=768, out_features=768, bias=True)
#             (value_linear): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1)
#           )
#           (self_output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#     )
#   )
#   (dense_f): Linear(in_features=3072, out_features=1, bias=True)
#   (ranking_embedding): BertEmbeddings(
#     (position_embeddings): Embedding(50, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): BertLayerNorm()
#     (dropout): Dropout(p=0.1)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %% [markdown]
# ## Reading the dataset to generate embedding

# %%
import os
import json

# creating the list of all the tables

# input will be a list of list [['table-0312-73' 'table-0312-60' '1']]
corpus = []

# List all files
for filename in os.listdir(corpus_folder):
    file_path = os.path.join(corpus_folder, filename)
    if os.path.isfile(file_path):
        print("Reading:", file_path)
        with open(file_path, "r") as f:
            data = json.load(f)
            data_keys = list(data.keys())
            # print(data_keys)
            for k in data_keys:
                corpus.append([k,k,1])
# Out:
# Reading: ../../dataset/spider/processing/corpus/re_tables-party_people.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-architecture.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-chinook_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-phone_market.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-flight_company.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-swimming.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-protein_institute.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-school_finance.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-department_management.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-orchestra.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-journal_committee.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-real_estate_properties.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-driving_school.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-county_public_safety.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-ship_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-employee_hire_evaluation.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-local_govt_mdm.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-dorm_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-election.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-riding_club.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-behavior_monitoring.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-student_transcripts_tracking.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-performance_attendance.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-soccer_2.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-match_season.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-music_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-culture_company.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-gymnast.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-party_host.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-imdb.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-car_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-sports_competition.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-tracking_software_problems.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-course_teach.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-college_2.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-restaurants.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-e_government.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-music_4.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-hr_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-race_track.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-tracking_share_transactions.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-store_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-cre_Theme_park.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-mountain_photos.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-twitter_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-device.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-musical.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-formula_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-museum_visit.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-club_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-machine_repair.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-cre_Doc_Template_Mgt.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-network_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-station_weather.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-pets_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-university_basketball.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-insurance_fnol.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-manufactory_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-music_2.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-wrestler.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-customers_campaigns_ecommerce.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-customers_card_transactions.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-ship_mission.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-school_player.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-academic.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-restaurant_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-product_catalog.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-flight_2.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-activity_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-assets_maintenance.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-icfp_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-network_2.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-cre_Drama_Workshop_Groups.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-geo.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-scholar.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-railway.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-tvshow.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-flight_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-epinions_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-customers_and_addresses.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-customer_deliveries.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-school_bus.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-apartment_rentals.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-dog_kennels.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-concert_singer.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-climbing.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-soccer_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-movie_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-book_2.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-solvency_ii.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-game_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-voter_2.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-loan_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-manufacturer.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-yelp.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-csu_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-entrepreneur.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-candidate_poll.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-body_builder.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-allergy_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-browser_web.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-bike_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-student_assessment.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-game_injury.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-perpetrator.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-cre_Docs_and_Epenses.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-insurance_and_eClaims.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-wine_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-company_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-products_gen_characteristics.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-entertainment_awards.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-hospital_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-shop_membership.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-world_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-decoration_competition.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-cre_Doc_Tracking_DB.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-debate.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-singer.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-insurance_policies.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-student_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-cinema.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-flight_4.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-aircraft.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-film_rank.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-department_store.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-customers_and_products_contacts.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-voter_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-cre_Doc_Control_Systems.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-local_govt_in_alabama.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-document_management.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-city_record.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-news_report.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-roller_coaster.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-election_representative.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-baseball_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-battle_death.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-poker_player.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-train_station.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-farm.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-company_employee.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-tracking_grants_for_research.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-products_for_hire.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-phone_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-college_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-college_3.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-tracking_orders.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-store_product.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-pilot_record.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-small_bank_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-storm_record.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-customer_complaints.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-inn_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-wta_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-coffee_shop.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-program_share.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-medicine_enzyme_interaction.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-e_learning.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-wedding.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-scientist_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-sakila_1.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-local_govt_and_lot.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-customers_and_invoices.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-company_office.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-theme_gallery.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-workshop_paper.json
# Reading: ../../dataset/spider/processing/corpus/re_tables-gas_company.json

# %%
print(len(corpus))

# corpus = corpus[:30]
# Out:
# 875

# %%
from data_reader import DataAndQueryReader
from torch.utils.data import DataLoader
from utils import pad_table_query

batch_size = 5

corpus_dataset = DataAndQueryReader(corpus,corpus_folder)
test_iter = DataLoader(corpus_dataset, batch_size=batch_size, shuffle=False, collate_fn=pad_table_query)
# Out:
# 100%|██████████| 875/875 [15:33<00:00,  1.07s/it]

# %%
corpus_embddding = []

for i, batch in enumerate(test_iter):
    tables, queries, all_tables_meta, all_query_meta, labels = batch

    labels = torch.FloatTensor(labels).to(device)
    
    with torch.no_grad():  # ensures no gradients are tracked
        outputs = model(tables, all_tables_meta, queries, all_query_meta)

    # detach and move to CPU before storing
    corpus_embddding.append(outputs)

# %%
print(len(corpus_embddding))
print(corpus_embddding[-1][0].shape[0])
# Out:
# 175
# 5

# %% [markdown]
# ### Reading the query table and generate its embedding

# %%
import os
import json

# creating the list of all the tables

# input will be a list of list [['table-0312-73' 'table-0312-60' '1']]
query = []

# List all files
for filename in os.listdir(query_folder):
    file_path = os.path.join(query_folder, filename)
    if os.path.isfile(file_path):
        print("Reading:", file_path)
        with open(file_path, "r") as f:
            data = json.load(f)
            data_keys = list(data.keys())
            # print(data_keys)
            for k in data_keys:
                for _ in range(batch_size):
                    query.append([k,k,1])
# Out:
# Reading: ../../dataset/spider/processing/query/re_tables-602.json
# Reading: ../../dataset/spider/processing/query/re_tables-68.json
# Reading: ../../dataset/spider/processing/query/re_tables-573.json
# Reading: ../../dataset/spider/processing/query/re_tables-24.json
# Reading: ../../dataset/spider/processing/query/re_tables-51.json
# Reading: ../../dataset/spider/processing/query/re_tables-173.json
# Reading: ../../dataset/spider/processing/query/re_tables-113.json
# Reading: ../../dataset/spider/processing/query/re_tables-523.json
# Reading: ../../dataset/spider/processing/query/re_tables-204.json
# Reading: ../../dataset/spider/processing/query/re_tables-260.json
# Reading: ../../dataset/spider/processing/query/re_tables-288.json
# Reading: ../../dataset/spider/processing/query/re_tables-338.json
# Reading: ../../dataset/spider/processing/query/re_tables-15.json
# Reading: ../../dataset/spider/processing/query/re_tables-153.json
# Reading: ../../dataset/spider/processing/query/re_tables-239.json
# Reading: ../../dataset/spider/processing/query/re_tables-534.json
# Reading: ../../dataset/spider/processing/query/re_tables-587.json
# Reading: ../../dataset/spider/processing/query/re_tables-575.json
# Reading: ../../dataset/spider/processing/query/re_tables-335.json
# Reading: ../../dataset/spider/processing/query/re_tables-437.json
# Reading: ../../dataset/spider/processing/query/re_tables-210.json
# Reading: ../../dataset/spider/processing/query/re_tables-54.json
# Reading: ../../dataset/spider/processing/query/re_tables-209.json
# Reading: ../../dataset/spider/processing/query/re_tables-46.json
# Reading: ../../dataset/spider/processing/query/re_tables-505.json
# Reading: ../../dataset/spider/processing/query/re_tables-391.json
# Reading: ../../dataset/spider/processing/query/re_tables-397.json
# Reading: ../../dataset/spider/processing/query/re_tables-107.json
# Reading: ../../dataset/spider/processing/query/re_tables-242.json
# Reading: ../../dataset/spider/processing/query/re_tables-536.json
# Reading: ../../dataset/spider/processing/query/re_tables-18.json
# Reading: ../../dataset/spider/processing/query/re_tables-359.json
# Reading: ../../dataset/spider/processing/query/re_tables-228.json
# Reading: ../../dataset/spider/processing/query/re_tables-605.json
# Reading: ../../dataset/spider/processing/query/re_tables-76.json
# Reading: ../../dataset/spider/processing/query/re_tables-620.json
# Reading: ../../dataset/spider/processing/query/re_tables-377.json
# Reading: ../../dataset/spider/processing/query/re_tables-119.json
# Reading: ../../dataset/spider/processing/query/re_tables-658.json
# Reading: ../../dataset/spider/processing/query/re_tables-312.json
# Reading: ../../dataset/spider/processing/query/re_tables-615.json
# Reading: ../../dataset/spider/processing/query/re_tables-227.json
# Reading: ../../dataset/spider/processing/query/re_tables-524.json
# Reading: ../../dataset/spider/processing/query/re_tables-140.json
# Reading: ../../dataset/spider/processing/query/re_tables-190.json
# Reading: ../../dataset/spider/processing/query/re_tables-411.json
# Reading: ../../dataset/spider/processing/query/re_tables-77.json
# Reading: ../../dataset/spider/processing/query/re_tables-305.json
# Reading: ../../dataset/spider/processing/query/re_tables-219.json
# Reading: ../../dataset/spider/processing/query/re_tables-648.json
# Reading: ../../dataset/spider/processing/query/re_tables-1.json
# Reading: ../../dataset/spider/processing/query/re_tables-294.json
# Reading: ../../dataset/spider/processing/query/re_tables-529.json
# Reading: ../../dataset/spider/processing/query/re_tables-97.json
# Reading: ../../dataset/spider/processing/query/re_tables-656.json
# Reading: ../../dataset/spider/processing/query/re_tables-645.json
# Reading: ../../dataset/spider/processing/query/re_tables-412.json
# Reading: ../../dataset/spider/processing/query/re_tables-229.json
# Reading: ../../dataset/spider/processing/query/re_tables-565.json
# Reading: ../../dataset/spider/processing/query/re_tables-182.json
# Reading: ../../dataset/spider/processing/query/re_tables-610.json
# Reading: ../../dataset/spider/processing/query/re_tables-143.json
# Reading: ../../dataset/spider/processing/query/re_tables-461.json
# Reading: ../../dataset/spider/processing/query/re_tables-99.json
# Reading: ../../dataset/spider/processing/query/re_tables-496.json
# Reading: ../../dataset/spider/processing/query/re_tables-336.json
# Reading: ../../dataset/spider/processing/query/re_tables-526.json
# Reading: ../../dataset/spider/processing/query/re_tables-3.json
# Reading: ../../dataset/spider/processing/query/re_tables-112.json
# Reading: ../../dataset/spider/processing/query/re_tables-341.json
# Reading: ../../dataset/spider/processing/query/re_tables-574.json
# Reading: ../../dataset/spider/processing/query/re_tables-631.json
# Reading: ../../dataset/spider/processing/query/re_tables-125.json
# Reading: ../../dataset/spider/processing/query/re_tables-409.json
# Reading: ../../dataset/spider/processing/query/re_tables-601.json
# Reading: ../../dataset/spider/processing/query/re_tables-520.json
# Reading: ../../dataset/spider/processing/query/re_tables-579.json
# Reading: ../../dataset/spider/processing/query/re_tables-594.json
# Reading: ../../dataset/spider/processing/query/re_tables-544.json
# Reading: ../../dataset/spider/processing/query/re_tables-593.json
# Reading: ../../dataset/spider/processing/query/re_tables-211.json
# Reading: ../../dataset/spider/processing/query/re_tables-249.json
# Reading: ../../dataset/spider/processing/query/re_tables-120.json
# Reading: ../../dataset/spider/processing/query/re_tables-482.json
# Reading: ../../dataset/spider/processing/query/re_tables-186.json
# Reading: ../../dataset/spider/processing/query/re_tables-340.json
# Reading: ../../dataset/spider/processing/query/re_tables-268.json
# Reading: ../../dataset/spider/processing/query/re_tables-567.json
# Reading: ../../dataset/spider/processing/query/re_tables-277.json
# Reading: ../../dataset/spider/processing/query/re_tables-367.json
# Reading: ../../dataset/spider/processing/query/re_tables-399.json
# Reading: ../../dataset/spider/processing/query/re_tables-157.json
# Reading: ../../dataset/spider/processing/query/re_tables-643.json
# Reading: ../../dataset/spider/processing/query/re_tables-45.json
# Reading: ../../dataset/spider/processing/query/re_tables-469.json
# Reading: ../../dataset/spider/processing/query/re_tables-57.json
# Reading: ../../dataset/spider/processing/query/re_tables-161.json
# Reading: ../../dataset/spider/processing/query/re_tables-35.json
# Reading: ../../dataset/spider/processing/query/re_tables-283.json
# Reading: ../../dataset/spider/processing/query/re_tables-192.json
# Reading: ../../dataset/spider/processing/query/re_tables-138.json
# Reading: ../../dataset/spider/processing/query/re_tables-506.json
# Reading: ../../dataset/spider/processing/query/re_tables-84.json
# Reading: ../../dataset/spider/processing/query/re_tables-385.json
# Reading: ../../dataset/spider/processing/query/re_tables-203.json
# Reading: ../../dataset/spider/processing/query/re_tables-255.json
# Reading: ../../dataset/spider/processing/query/re_tables-202.json
# Reading: ../../dataset/spider/processing/query/re_tables-67.json
# Reading: ../../dataset/spider/processing/query/re_tables-222.json
# Reading: ../../dataset/spider/processing/query/re_tables-199.json
# Reading: ../../dataset/spider/processing/query/re_tables-467.json
# Reading: ../../dataset/spider/processing/query/re_tables-370.json
# Reading: ../../dataset/spider/processing/query/re_tables-169.json
# Reading: ../../dataset/spider/processing/query/re_tables-248.json
# Reading: ../../dataset/spider/processing/query/re_tables-218.json
# Reading: ../../dataset/spider/processing/query/re_tables-422.json
# Reading: ../../dataset/spider/processing/query/re_tables-172.json
# Reading: ../../dataset/spider/processing/query/re_tables-149.json
# Reading: ../../dataset/spider/processing/query/re_tables-369.json
# Reading: ../../dataset/spider/processing/query/re_tables-636.json
# Reading: ../../dataset/spider/processing/query/re_tables-464.json
# Reading: ../../dataset/spider/processing/query/re_tables-101.json

# %%
print(len(query))

# query = query[:50]
# query
# Out:
# 3290

# %%
from data_reader import DataAndQueryReader
from torch.utils.data import DataLoader
from utils import pad_table_query


query_dataset = DataAndQueryReader(query,query_folder)

query_iter = DataLoader(query_dataset, batch_size=batch_size, shuffle=False, collate_fn=pad_table_query)
# Out:
# 100%|██████████| 3290/3290 [01:43<00:00, 31.77it/s]

# %%
# print(query[1090])
# print(query[1135])
# print(query[1140])
# print(query[1330])

# for bird dataset
# print(query[5955])

# %%
query_embddding = []

for i, batch in enumerate(query_iter):
    tables, queries, all_tables_meta, all_query_meta, labels = batch

    labels = torch.FloatTensor(labels).to(device)
    
    with torch.no_grad():  # ensures no gradients are tracked
        outputs = model(tables, all_tables_meta, queries, all_query_meta)

    # detach and move to CPU before storing
    query_embddding.append(outputs)

# %%
print(query_embddding[-1][0][:4].shape)
# Out:
# torch.Size([4, 46, 768])

# %% [markdown]
# ### Get the similarity for query with corpus

# %%
res = []

for q in range(len(query_embddding)):
    r = []
    # print(q)
    for c in range(len(corpus_embddding)):
        # print(c)
        with torch.no_grad():  # ensures no gradients are tracked
            # rnk = model.get_similarity_custom(query_embddding[q][0][:min(batch_size, corpus_embddding[c][0].shape[0])], query_embddding[q][1][:min(batch_size, corpus_embddding[c][0].shape[0])], query_embddding[q][2][:min(batch_size, corpus_embddding[c][0].shape[0])], query_embddding[q][3][:min(batch_size, corpus_embddding[c][0].shape[0])], corpus_embddding[c][0], corpus_embddding[c][1], corpus_embddding[c][2], corpus_embddding[c][3])
            rnk = model.get_similarity_cls(query_embddding[q][0][:min(batch_size, corpus_embddding[c][0].shape[0])], query_embddding[q][1][:min(batch_size, corpus_embddding[c][0].shape[0])], query_embddding[q][2][:min(batch_size, corpus_embddding[c][0].shape[0])], query_embddding[q][3][:min(batch_size, corpus_embddding[c][0].shape[0])], corpus_embddding[c][0], corpus_embddding[c][1], corpus_embddding[c][2], corpus_embddding[c][3])
        r.append(rnk)
    res.append(r)

# %%
len(res[0][0])
# Out:
# 5

# %%
print(res[0])
# Out:
958, 0.5785, 0.6182], device='cuda:3'), tensor([0.6892, 0.6843, 0.6708, 0.6274, 0.6366], device='cuda:3'), tensor([0.5852, 0.5887, 0.6828, 0.6006, 0.6932], device='cuda:3'), tensor([0.7231, 0.6613, 0.7049, 0.7088, 0.6911], device='cuda:3'), tensor([0.6952, 0.7171, 0.6959, 0.7138, 0.7033], device='cuda:3'), tensor([0.7191, 0.6033, 0.6898, 0.7152, 0.6694], device='cuda:3'), tensor([0.4929, 0.6618, 0.7162, 0.5985, 0.6523], device='cuda:3'), tensor([0.6618, 0.6318, 0.7068, 0.6846, 0.5284], device='cuda:3'), tensor([0.6058, 0.5198, 0.4231, 0.5592, 0.6377], device='cuda:3'), tensor([0.5182, 0.4650, 0.4101, 0.4977, 0.5100], device='cuda:3'), tensor([0.4793, 0.3588, 0.5603, 0.5622, 0.6633], device='cuda:3'), tensor([0.7084, 0.6085, 0.6616, 0.6898, 0.6448], device='cuda:3'), tensor([0.5641, 0.6723, 0.6992, 0.6317, 0.5316], device='cuda:3'), tensor([0.5616, 0.5956, 0.5949, 0.6847, 0.6379], device='cuda:3'), tensor([0.6061, 0.5136, 0.5272, 0.6382, 0.5684], device='cuda:3'), tensor([0.6551, 0.7235, 0.8074, 0.5677, 0.5507], device='cuda:3'), tensor([0.7214, 0.6294, 0.6357, 0.6040, 0.6096], device='cuda:3'), tensor([0.6114, 0.6099, 0.6400, 0.6885, 0.6396], device='cuda:3'), tensor([0.6055, 0.6538, 0.5851, 0.6416, 0.6072 ...

# %%
corpus_list = []

for c in corpus:
    corpus_list.append(c[0])

# %%
print(len(corpus_list))
# Out:
# 875

# %%
query_list = []
for q in query:
    if q[0] not in query_list:
        query_list.append(q[0])

# %%
print(len(query_list))
# Out:
# 658

# %%
# checking if the folder exist in that path

if not os.path.exists(result_path):
    os.makedirs(result_path)
    print("folder created...")
else:
    print("folder already exist...")
# Out:
# folder created...

# %%
from torch import nn
m = nn.Sigmoid()

for idx, r in enumerate(res):
    out = torch.cat(r, dim=0)
    out_s = m(out)

    res_dic = {}

    for o in range(out_s.shape[0]):
        if out_s[o].item() not in res_dic.keys():
            res_dic[out_s[o].item()] = []
        res_dic[out_s[o].item()].append(o)

    res_dic_key = list(res_dic.keys())
    sorted_res_dic_key = sorted(res_dic_key, reverse=True)
    
    with open(os.path.join(result_path, query_list[idx]), 'w') as fp:
        for k in sorted_res_dic_key:
            fp.write(f'{k} : ')
            for j in res_dic[k]:
                fp.write(f'{corpus_list[j]} ')
            
            fp.write('\n')

# %%
# from data_reader import DataAndQueryReader
# folds_path= "wikitables_similarity_folds.npy"
# data_folder = "../../dataset/spider/processing/query"

# kfolds = np.load(folds_path, allow_pickle=True)
# kfolds = kfolds[()]

# print(kfolds)

# for fold_index,(train, test) in enumerate(kfolds):

#     print("train length:", len(train))
#     print("test length:",len(test))

#     train_d = train[:2]
#     print(train_d)

#     test_d = test[:2]
#     print(test_d)

#     # train_dataset = DataAndQueryReader(train_d,data_folder)
#     # print('size of training = {}'.format(len(train_dataset)))

#     # print(train_dataset)
